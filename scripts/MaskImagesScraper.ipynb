# %%
# !pip install -q jmd_imagescraper
# Out:
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
import shutil
path = os.getcwd()
abspath = os.path.abspath(os.path.join(path, os.pardir))

# %%
from pathlib import Path

folder = 'imagesMasks'
root = f'{abspath}/{folder}'

if not os.path.exists(root):
    os.mkdir(root)

from jmd_imagescraper.core import * # dont't worry, it's designed to work with import *

# %%
label = 'Masks'
search1 = 'corona mask'
search2 = 'ffp2 mask'

results = 477;

duckduckgo_search(root, label, search1, max_results=results)
duckduckgo_search(root, label, search2, max_results=results)
# Out:
# Duckduckgo search: ffp2 mask
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='477' class='' max='477' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [477/477 00:37<00:00 Images downloaded]
#     </div>
# [PosixPath('/tf/src/imagesMasks/Masks/478_ab4f047b.jpg'),
#  PosixPath('/tf/src/imagesMasks/Masks/479_adc1c7cb.jpg'),
#  PosixPath('/tf/src/imagesMasks/Masks/480_c383b391.jpg'),
#  PosixPath('/tf/src/imagesMasks/Masks/481_ad6f074b.jpg'),
# ...

# %%
label = 'Faces'
search = 'person face'

results = 477;

duckduckgo_search(root, label, search, max_results=results)
# Out:
# Duckduckgo search: person face
# ...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='477' class='' max='477' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [477/477 00:33<00:00 Images downloaded]
#     </div>
# [PosixPath('/tf/src/imagesMasks/Faces/001_c5efcb0c.jpg'),
#  PosixPath('/tf/src/imagesMasks/Faces/002_09c3e20e.jpg'),
#  PosixPath('/tf/src/imagesMasks/Faces/003_e673db7b.jpg'),
#  PosixPath('/tf/src/imagesMasks/Faces/004_6bcef322.jpg'),
# ...
