# %%
import os
import tensorflow as tf
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

# %%
text_file = open("./assets/list_promis_own.txt", "r")
query_array = text_file.read().split(',\n')
print(query_array)
# Out:
# ['LewisHamilton', 'SebastianVettel', 'MaxVerstappen', 'KarlLauterbach', 'CristianoRonaldo', 'LionelMessi', 'EdSheeran', 'TomCruise', 'HeleneFischer', 'ArnoldSchwarzenegger', 'GüntherJauch', 'StefanRaab', 'HeidiKlum', 'ManuelNeuer', "ElyasM'barek", 'JudithRakers', 'AngelaMerkel', 'WladimirPutin', 'OlafScholz', 'JoeBiden', 'DonaldTrump', 'ChristianLindner', 'AnnalenaBaerbock', 'ElonMusk', 'JeffBezos', 'BarackObama', 'ChrisPratt', 'XiJinping', 'DwayneJohnson', 'MacKenzieScott', 'AnthonyFauci', 'GeorgeClooney', 'BradPitt', 'KobeBryant', "ShaquilleO'Neal", 'VinDiesel', 'JasonMomoa', 'ChrisHemsworth', 'TomHiddleston', 'BenedictCumberbatch', 'ChadwickBoseman', 'LeBronJames', 'MichaelJordan', 'MichaelJackson', 'LeonardoDiCaprio', 'TomHanks', 'WillSmith', 'DenzelWashington', 'RobertDowneyJr', 'TomHardy', 'MorganFreeman', 'NovakDjokovic', 'RafaelNadal', 'RogerFederer', 'ChristianBale', 'SylvesterStallone']

# %%
print(os.getcwd())

path = os.getcwd()
abspath = os.path.abspath(os.path.join(path, os.pardir))

datapath = abspath + "/datasetV2/"

chosen_tf_model_folder = 'TF_V2';  # entry which model you want to test (different versions)

outpath =  f'{abspath}/models/{chosen_tf_model_folder}/'
# Out:
# /tf/src/scripts

# %%
def read_train_val_test(dataset_dir, label_map):
    return tuple(map(lambda set_: object_detector.DataLoader.from_pascal_voc(images_dir=os.path.join(dataset_dir, set_), annotations_dir=os.path.join(dataset_dir, set_), label_map=label_map), ("train", "val", "test")))

# %%
labelmap = query_array
train_data, validation_data, test_data = read_train_val_test(datapath, labelmap)
# Out:
# INFO:tensorflow:Cache will be stored in /tmp/tmpiy577d9w with prefix filename 7bee435cfee6949ada7cad38d32e815e. Cache_prefix is /tmp/tmpiy577d9w/7bee435cfee6949ada7cad38d32e815e
# INFO:tensorflow:On image 0
# INFO:tensorflow:On image 100
# INFO:tensorflow:On image 200
# INFO:tensorflow:On image 300
# INFO:tensorflow:On image 400
# INFO:tensorflow:On image 500
# INFO:tensorflow:On image 600
# INFO:tensorflow:On image 700
# INFO:tensorflow:On image 800
# INFO:tensorflow:On image 900
# INFO:tensorflow:On image 1000
# INFO:tensorflow:On image 1100
# INFO:tensorflow:On image 1200
# INFO:tensorflow:On image 1300
# INFO:tensorflow:On image 1400
# INFO:tensorflow:On image 1500
# INFO:tensorflow:On image 1600
# INFO:tensorflow:On image 1700
# INFO:tensorflow:On image 1800
# INFO:tensorflow:On image 1900
# INFO:tensorflow:On image 2000
# INFO:tensorflow:On image 2100
# INFO:tensorflow:On image 2200
# INFO:tensorflow:On image 2300
# INFO:tensorflow:On image 2400
# INFO:tensorflow:On image 2500
# INFO:tensorflow:On image 2600
# INFO:tensorflow:On image 2700
# INFO:tensorflow:On image 2800
# INFO:tensorflow:On image 2900
# INFO:tensorflow:On image 3000
# INFO:tensorflow:On image 3100
# INFO:tensorflow:On image 3200
# INFO:tensorflow:On image 3300
# INFO:tensorflow:On image 3400
# INFO:tensorflow:On image 3500
# INFO:tensorflow:On image 3600
# INFO:tensorflow:On image 3700
# INFO:tensorflow:On image 3800
# INFO:tensorflow:On image 3900
# INFO:tensorflow:On image 4000
# INFO:tensorflow:On image 4100
# INFO:tensorflow:On image 4200
# INFO:tensorflow:On image 4300
# INFO:tensorflow:On image 4400
# INFO:tensorflow:On image 4500
# INFO:tensorflow:On image 4600
# INFO:tensorflow:On image 4700
# INFO:tensorflow:On image 4800
# INFO:tensorflow:On image 4900
# INFO:tensorflow:On image 5000
# INFO:tensorflow:On image 5100
# INFO:tensorflow:On image 5200
# INFO:tensorflow:On image 5300
# INFO:tensorflow:On image 5400
# INFO:tensorflow:On image 5500
# INFO:tensorflow:On image 5600
# INFO:tensorflow:On image 5700
# INFO:tensorflow:On image 5800
# INFO:tensorflow:On image 5900
# INFO:tensorflow:On image 6000
# INFO:tensorflow:On image 6100
# INFO:tensorflow:On image 6200
# INFO:tensorflow:On image 6300
# INFO:tensorflow:On image 6400
# INFO:tensorflow:On image 6500
# INFO:tensorflow:On image 6600
# INFO:tensorflow:On image 6700
# INFO:tensorflow:On image 6800
# INFO:tensorflow:On image 6900
# INFO:tensorflow:On image 7000
# INFO:tensorflow:On image 7100
# INFO:tensorflow:On image 7200
# INFO:tensorflow:On image 7300
# INFO:tensorflow:On image 7400
# INFO:tensorflow:On image 7500
# INFO:tensorflow:On image 7600
# INFO:tensorflow:On image 7700
# INFO:tensorflow:On image 7800
# INFO:tensorflow:On image 7900
# INFO:tensorflow:On image 8000
# INFO:tensorflow:On image 8100
# INFO:tensorflow:On image 8200
# INFO:tensorflow:On image 8300
# INFO:tensorflow:On image 8400
# INFO:tensorflow:On image 8500
# INFO:tensorflow:On image 8600
# INFO:tensorflow:On image 8700
# INFO:tensorflow:On image 8800
# INFO:tensorflow:On image 8900
# INFO:tensorflow:On image 9000
# INFO:tensorflow:On image 9100
# INFO:tensorflow:On image 9200
# INFO:tensorflow:On image 9300
# INFO:tensorflow:On image 9400
# INFO:tensorflow:On image 9500
# INFO:tensorflow:On image 9600
# INFO:tensorflow:On image 9700
# INFO:tensorflow:On image 9800
# INFO:tensorflow:On image 9900
# INFO:tensorflow:On image 10000
# INFO:tensorflow:On image 10100
# INFO:tensorflow:On image 10200
# INFO:tensorflow:On image 10300
# INFO:tensorflow:On image 10400
# INFO:tensorflow:On image 10500
# INFO:tensorflow:On image 10600
# INFO:tensorflow:On image 10700
# INFO:tensorflow:On image 10800
# INFO:tensorflow:On image 10900
# INFO:tensorflow:On image 11000
# INFO:tensorflow:On image 11100
# INFO:tensorflow:On image 11200
# INFO:tensorflow:On image 11300
# INFO:tensorflow:On image 11400
# INFO:tensorflow:On image 11500
# INFO:tensorflow:On image 11600
# INFO:tensorflow:On image 11700
# INFO:tensorflow:On image 11800
# INFO:tensorflow:Cache will be stored in /tmp/tmpb487hgwf with prefix filename 5eea5b9312bd58fd9725d2a3a736893c. Cache_prefix is /tmp/tmpb487hgwf/5eea5b9312bd58fd9725d2a3a736893c
# INFO:tensorflow:On image 0
# INFO:tensorflow:On image 100
# INFO:tensorflow:On image 200
# INFO:tensorflow:On image 300
# INFO:tensorflow:On image 400
# INFO:tensorflow:On image 500
# INFO:tensorflow:On image 600
# INFO:tensorflow:On image 700
# INFO:tensorflow:On image 800
# INFO:tensorflow:On image 900
# INFO:tensorflow:On image 1000
# INFO:tensorflow:On image 1100
# INFO:tensorflow:On image 1200
# INFO:tensorflow:On image 1300
# INFO:tensorflow:On image 1400
# INFO:tensorflow:On image 1500
# INFO:tensorflow:On image 1600
# INFO:tensorflow:On image 1700
# INFO:tensorflow:On image 1800
# INFO:tensorflow:On image 1900
# INFO:tensorflow:On image 2000
# INFO:tensorflow:On image 2100
# INFO:tensorflow:On image 2200
# INFO:tensorflow:On image 2300
# INFO:tensorflow:On image 2400
# INFO:tensorflow:On image 2500
# INFO:tensorflow:Cache will be stored in /tmp/tmpvyry3y4s with prefix filename fd42585a6188df7d3abc4e516ad0ebb5. Cache_prefix is /tmp/tmpvyry3y4s/fd42585a6188df7d3abc4e516ad0ebb5
# INFO:tensorflow:On image 0
# INFO:tensorflow:On image 100
# INFO:tensorflow:On image 200
# INFO:tensorflow:On image 300
# INFO:tensorflow:On image 400
# INFO:tensorflow:On image 500
# INFO:tensorflow:On image 600
# INFO:tensorflow:On image 700
# INFO:tensorflow:On image 800
# INFO:tensorflow:On image 900
# INFO:tensorflow:On image 1000
# INFO:tensorflow:On image 1100
# INFO:tensorflow:On image 1200
# INFO:tensorflow:On image 1300
# INFO:tensorflow:On image 1400
# INFO:tensorflow:On image 1500
# INFO:tensorflow:On image 1600
# INFO:tensorflow:On image 1700
# INFO:tensorflow:On image 1800
# INFO:tensorflow:On image 1900
# INFO:tensorflow:On image 2000
# INFO:tensorflow:On image 2100
# INFO:tensorflow:On image 2200
# INFO:tensorflow:On image 2300
# INFO:tensorflow:On image 2400

# %%
import time

import cv2
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def to_json(self):
        return {
            "x": self.x,
            "y": self.y,
        }

    def __str__(self):
        return str(self.to_json())

class BoundingBox:
    def __init__(self, xmin, ymin, xmax, ymax):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        self.center = Point((xmin + xmax) // 2, (ymin + ymax) // 2)
        self.width = xmax - xmin
        self.height = ymax - ymin
        self.area = self.width * self.height

    def to_json(self):
        return {
            "xmin": self.xmin,
            "ymin": self.ymin,
            "xmax": self.xmax,
            "ymax": self.ymax,
        }

    def __str__(self):
        return str(self.to_json())

class Detection:
    def __init__(self, class_, confidence, xmin, ymin, xmax, ymax):
        self.class_ = class_
        self.confidence = confidence
        self.bounding_box = BoundingBox(xmin=xmin, ymin=ymin, xmax=xmax, ymax=ymax)

    def to_json(self):
        return {
            "class": self.class_,
            "confidence": self.confidence,
            "box": self.bounding_box.to_json(),
        }

    def __str__(self):
        return str(self.to_json())


class EfficientDetLite:
    def __init__(self, model_path, labelmap):
        self.interpreter = tf.lite.Interpreter(model_path=model_path)
        self.interpreter.allocate_tensors()

        # iti = input tensor index
        input_details = self.interpreter.get_input_details()
        self.iti_image = input_details[0]["index"]
        self.it_image_dtype = input_details[0]["dtype"]
        self.it_image_width = input_details[0]["shape"][2]
        self.it_image_height = input_details[0]["shape"][1]

        # oti = output tensor index
        output_details = self.interpreter.get_output_details()
        self.oti_bounding_boxes = output_details[1]["index"]
        self.oti_classes = output_details[3]["index"]
        self.oti_confidences = output_details[0]["index"]

        self.labelmap = labelmap

    def detect(self, image, threshold=0):
        input_tensor = self.prepare_image(image)
        self.interpreter.set_tensor(self.iti_image, input_tensor)
        self.interpreter.invoke()

        bounding_boxes = self.interpreter.get_tensor(self.oti_bounding_boxes)[0]
        classes = self.interpreter.get_tensor(self.oti_classes)[0]
        confidences = self.interpreter.get_tensor(self.oti_confidences)[0]
        detections = zip(classes, bounding_boxes, confidences)
        detections = filter(lambda x: x[2] >= threshold, detections)

        def tensors2detection(x):
            def clamp(n, min_, max_):
                return max(min(max_, n), min_)

            xmin = clamp(int(round(x[1][1] * image.shape[1])), 0, image.shape[1])
            ymin = clamp(int(round(x[1][0] * image.shape[0])), 0, image.shape[0])
            xmax = clamp(int(round(x[1][3] * image.shape[1])), 0, image.shape[1])
            ymax = clamp(int(round(x[1][2] * image.shape[0])), 0, image.shape[0])
            name = str(self.labelmap[int(x[0])])
            confidence = float(x[2])

            detection = Detection(name, confidence, xmin, ymin, xmax, ymax)
            return detection

        detections = map(lambda x: tensors2detection(x), detections)
        detections = list(detections)
        return detections

    def prepare_image(self, image):
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (self.it_image_width, self.it_image_height), interpolation=cv2.INTER_NEAREST)
        tensor = np.reshape(image, (1, self.it_image_height, self.it_image_width, 3))
        tensor = tensor.astype(self.it_image_dtype)
        return tensor

def show_image(image, label=None, scale=1):
    show_images([image], labels=[label] if label is not None else None, scale=scale)


def show_images(images, labels=None, scale=1):
    figsize = plt.rcParams["figure.figsize"]
    plt.figure(figsize=(figsize[0] * scale, figsize[1] * scale))
    for i in range(len(images)):
        plt.subplot(1, len(images), i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        image = cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB)
        plt.imshow(image, cmap=plt.cm.binary)
        if labels is not None:
            plt.xlabel(labels[i])
    plt.show()


def show_detection(image, detection, scale=1, thickness=1, colors=None, confidence=True):
    show_image(draw_detections(image,
                               [detection],
                               scale=scale,
                               thickness=thickness,
                               colors=colors,
                               confidence=confidence))


def show_detections(image, detections, scale=1, thickness=1, colors=None, confidence=True):
    show_image(draw_detections(image,
                               detections,
                               scale=scale,
                               thickness=thickness,
                               colors=colors,
                               confidence=confidence))


def draw_detection(image, detection, scale=1, thickness=1, colors=None, confidence=True):
    return draw_detections(image, [detection], scale, thickness, colors, confidence)


def draw_detections(image, detections, scale=1, thickness=1, colors=None, confidence=True):
    colors = {} if colors is None else {k: tuple(reversed(v)) for k, v in colors.items()}
    result = image.copy()
    for detection in detections:
        #print(detection.class_)
        xmin = int(detection.bounding_box.xmin)
        ymin = int(detection.bounding_box.ymin)
        xmax = int(detection.bounding_box.xmax)
        ymax = int(detection.bounding_box.ymax)
        color = colors.get(detection.class_)
        if color is None:
            color = (206, 255, 0)
        result = cv2.rectangle(result, (xmin, ymin), (xmax, ymax), color, thickness)
        if confidence:
            text = f'{detection.class_}: ' + "{:.2f}".format(float(detection.confidence))
            font = cv2.FONT_HERSHEY_SIMPLEX
            textsize = cv2.getTextSize(text, font, scale, thickness)[0]
            result = cv2.putText(result,
                                 text,
                                 (
                                     ((xmin + xmax) - textsize[0]) // 2,
                                     ((ymin + ymax) + textsize[1]) // 2
                                 ),
                                 font,
                                 scale,
                                 color,
                                 thickness,
                                 cv2.LINE_AA)
    return result

# %%
model = EfficientDetLite(outpath + 'model.tflite', labelmap)

# %%
image = cv2.imread(datapath + 'test/193_424ab9c1.jpg') # change to exisiting image

#image = cv2.imread('/tf/src/test/lm_cr.jpg')

print(image)

detections = model.detect(image, threshold=0.1)

for detection in detections:
  print(detection)

show_detections(image, detections, thickness=2)

new = draw_detections(image, detections, thickness=2)
plt.imshow(cv2.cvtColor(new, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [[[ 10   7   3]
#   [ 10   7   3]
#   [ 10   7   3]
#   ...
#   [ 10   7   3]
#   [  8   5   1]
#   [  8   5   1]]
#
#  [[ 10   7   3]
#   [ 10   7   3]
#   [ 10   7   3]
#   ...
#   [ 10   7   3]
#   [  8   5   1]
#   [  8   5   1]]
#
#  [[ 10   7   3]
#   [ 10   7   3]
#   [ 10   7   3]
#   ...
#   [ 10   7   3]
#   [  9   6   2]
#   [  9   6   2]]
#
#  ...
#
#  [[  0   3  26]
#   [  0   0  22]
#   [  0   4  25]
#   ...
#   [ 89 126 140]
#   [ 95 132 146]
#   [ 96 133 147]]
#
#  [[ 57  66  86]
#   [ 41  53  71]
#   [ 36  48  66]
#   ...
#   [101 138 152]
#   [110 147 161]
#   [111 148 162]]
#
#  [[ 60  66  85]
#   [ 40  47  66]
#   [ 34  41  60]
#   ...
#   [101 138 152]
#   [111 148 162]
#   [112 149 163]]]
# {'class': 'LeBronJames', 'confidence': 0.16796875, 'box': {'xmin': 231, 'ymin': 29, 'xmax': 283, 'ymax': 75}}
# {'class': 'LeBronJames', 'confidence': 0.140625, 'box': {'xmin': 4, 'ymin': 186, 'xmax': 35, 'ymax': 213}}
# {'class': 'LeBronJames', 'confidence': 0.125, 'box': {'xmin': 370, 'ymin': 177, 'xmax': 396, 'ymax': 201}}

# %%
import cv2

# %%
import os
import ffmpeg
import numpy as np
path = os.getcwd()
abspath = os.path.abspath(os.path.join(path, os.pardir))

in_filename = f'{abspath}/ffmpegTest/merkel3.mp4'
out_filename = f'{abspath}/ffmpegTest/merkel3_1.mp4'

# %%
def detect2(in_frame):
    try:
        img = in_frame
        
        detections = model.detect(img, threshold=0.4)
        
        for detection in detections:
            print(detection)
        
        new = draw_detections(img, detections, thickness=2)
                
        return new
        
    except ValueError:
        print(ValueError)
        print(framePath + frame)
        
    except TypeError:
        return cv2.cvtColor(new_img, cv2.COLOR_RGB2BGR)

# %%
probe = ffmpeg.probe(in_filename)
height = probe['streams'][0]['height']
width = probe['streams'][0]['width']
nb_frames = probe['streams'][0]['nb_frames']

# %%
def analyse(in_filename, out_filename):
    process1 = (
    ffmpeg
    .input(in_filename)
    .output('pipe:', format='rawvideo', pix_fmt='rgb24', vframes=nb_frames)
    .run_async(pipe_stdout=True)
    )

    process2 = (
    ffmpeg
    .input('pipe:', format='rawvideo', pix_fmt='rgb24', s='{}x{}'.format(width, height))
    .output(out_filename, pix_fmt='yuv420p')
    .overwrite_output()
    .run_async(pipe_stdin=True)
    )

    while True:
        in_bytes = process1.stdout.read(width * height * 3)
        if not in_bytes:
            break
        in_frame = (
            np
            .frombuffer(in_bytes, np.uint8)
            .reshape([height, width, 3])
        )

        # See examples/tensorflow_stream.py:
        out_frame = detect2(in_frame)

        process2.stdin.write(
            out_frame
            .astype(np.uint8)
            .tobytes()
        )

    process2.stdin.close()
    process1.wait()
    process2.wait()

# %%
analyse(in_filename, out_filename)
# Out:
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 358, 'ymin': 73, 'xmax': 544, 'ymax': 177}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 359, 'ymin': 73, 'xmax': 542, 'ymax': 176}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 359, 'ymin': 73, 'xmax': 542, 'ymax': 176}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 357, 'ymin': 73, 'xmax': 540, 'ymax': 176}}
# {'class': 'AngelaMerkel', 'confidence': 0.44140625, 'box': {'xmin': 358, 'ymin': 74, 'xmax': 539, 'ymax': 176}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 359, 'ymin': 73, 'xmax': 542, 'ymax': 176}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 363, 'ymin': 74, 'xmax': 533, 'ymax': 170}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 362, 'ymin': 74, 'xmax': 534, 'ymax': 170}}
# {'class': 'AngelaMerkel', 'confidence': 0.44140625, 'box': {'xmin': 363, 'ymin': 72, 'xmax': 533, 'ymax': 169}}
# {'class': 'AngelaMerkel', 'confidence': 0.44140625, 'box': {'xmin': 362, 'ymin': 74, 'xmax': 534, 'ymax': 172}}
# {'class': 'AngelaMerkel', 'confidence': 0.44140625, 'box': {'xmin': 362, 'ymin': 74, 'xmax': 534, 'ymax': 170}}
# {'class': 'AngelaMerkel', 'confidence': 0.44140625, 'box': {'xmin': 359, 'ymin': 74, 'xmax': 533, 'ymax': 172}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 359, 'ymin': 74, 'xmax': 533, 'ymax': 172}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 357, 'ymin': 72, 'xmax': 531, 'ymax': 172}}
# {'class': 'AngelaMerkel', 'confidence': 0.5859375, 'box': {'xmin': 360, 'ymin': 73, 'xmax': 532, 'ymax': 171}}
# {'class': 'AngelaMerkel', 'confidence': 0.640625, 'box': {'xmin': 361, 'ymin': 72, 'xmax': 535, 'ymax': 172}}
# {'class': 'AngelaMerkel', 'confidence': 0.61328125, 'box': {'xmin': 360, 'ymin': 73, 'xmax': 532, 'ymax': 171}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 359, 'ymin': 73, 'xmax': 529, 'ymax': 170}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 359, 'ymin': 76, 'xmax': 529, 'ymax': 172}}
# {'class': 'AngelaMerkel', 'confidence': 0.5859375, 'box': {'xmin': 356, 'ymin': 77, 'xmax': 532, 'ymax': 176}}
# {'class': 'AngelaMerkel', 'confidence': 0.61328125, 'box': {'xmin': 360, 'ymin': 78, 'xmax': 532, 'ymax': 175}}
# {'class': 'AngelaMerkel', 'confidence': 0.734375, 'box': {'xmin': 360, 'ymin': 79, 'xmax': 532, 'ymax': 176}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 363, 'ymin': 80, 'xmax': 537, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 366, 'ymin': 77, 'xmax': 548, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 366, 'ymin': 75, 'xmax': 548, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 362, 'ymin': 75, 'xmax': 545, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 369, 'ymin': 75, 'xmax': 548, 'ymax': 175}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 369, 'ymin': 76, 'xmax': 548, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 370, 'ymin': 75, 'xmax': 549, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 373, 'ymin': 75, 'xmax': 552, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 370, 'ymin': 77, 'xmax': 549, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 370, 'ymin': 77, 'xmax': 549, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 374, 'ymin': 77, 'xmax': 551, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 377, 'ymin': 78, 'xmax': 553, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 380, 'ymin': 78, 'xmax': 554, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 381, 'ymin': 78, 'xmax': 557, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 379, 'ymin': 77, 'xmax': 560, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 381, 'ymin': 78, 'xmax': 559, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 380, 'ymin': 76, 'xmax': 564, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 381, 'ymin': 75, 'xmax': 567, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 383, 'ymin': 76, 'xmax': 566, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 383, 'ymin': 76, 'xmax': 566, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 387, 'ymin': 76, 'xmax': 566, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 384, 'ymin': 71, 'xmax': 570, 'ymax': 175}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 854, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 0, 'ymin': 2, 'xmax': 854, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'MacKenzieScott', 'confidence': 0.47265625, 'box': {'xmin': 5, 'ymin': 0, 'xmax': 849, 'ymax': 480}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'MacKenzieScott', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'MacKenzieScott', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.6640625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.6640625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.6640625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.640625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.640625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.6640625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 5, 'ymin': 0, 'xmax': 849, 'ymax': 480}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 0, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 0, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'AngelaMerkel', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 0, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 386, 'ymin': 81, 'xmax': 563, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 10, 'ymin': 0, 'xmax': 844, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 388, 'ymin': 81, 'xmax': 565, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 386, 'ymin': 81, 'xmax': 563, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 385, 'ymin': 81, 'xmax': 561, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 10, 'ymin': 0, 'xmax': 844, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 386, 'ymin': 81, 'xmax': 563, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 386, 'ymin': 81, 'xmax': 563, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 385, 'ymin': 81, 'xmax': 561, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 386, 'ymin': 79, 'xmax': 560, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 10, 'ymin': 0, 'xmax': 844, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 386, 'ymin': 79, 'xmax': 560, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 385, 'ymin': 80, 'xmax': 564, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 382, 'ymin': 82, 'xmax': 559, 'ymax': 182}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 5, 'ymin': 0, 'xmax': 849, 'ymax': 471}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 372, 'ymin': 80, 'xmax': 556, 'ymax': 184}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 364, 'ymin': 81, 'xmax': 549, 'ymax': 185}}
# {'class': 'AngelaMerkel', 'confidence': 0.640625, 'box': {'xmin': 364, 'ymin': 80, 'xmax': 549, 'ymax': 186}}
# {'class': 'AngelaMerkel', 'confidence': 0.81640625, 'box': {'xmin': 355, 'ymin': 82, 'xmax': 538, 'ymax': 185}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 355, 'ymin': 83, 'xmax': 529, 'ymax': 181}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 0, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 0, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 0, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 5, 'ymin': 3, 'xmax': 849, 'ymax': 477}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 9, 'ymin': 0, 'xmax': 845, 'ymax': 473}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 9, 'ymin': 0, 'xmax': 845, 'ymax': 473}}
# {'class': 'AngelaMerkel', 'confidence': 0.6640625, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 845, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 472}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 15, 'ymin': 3, 'xmax': 850, 'ymax': 477}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 0, 'ymin': 0, 'xmax': 854, 'ymax': 474}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 15, 'ymin': 3, 'xmax': 850, 'ymax': 477}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 5, 'ymin': 5, 'xmax': 849, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 854, 'ymax': 477}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.6640625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.69140625, 'box': {'xmin': 4, 'ymin': 3, 'xmax': 850, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 349, 'ymin': 83, 'xmax': 515, 'ymax': 177}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 9, 'ymin': 0, 'xmax': 854, 'ymax': 473}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 854, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 854, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.44140625, 'box': {'xmin': 9, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 358, 'ymin': 84, 'xmax': 511, 'ymax': 173}}
# {'class': 'AngelaMerkel', 'confidence': 0.44140625, 'box': {'xmin': 9, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 351, 'ymin': 84, 'xmax': 508, 'ymax': 173}}
# {'class': 'AngelaMerkel', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 473}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 854, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 854, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 854, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 348, 'ymin': 85, 'xmax': 512, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 348, 'ymin': 84, 'xmax': 512, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 347, 'ymin': 83, 'xmax': 513, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 346, 'ymin': 83, 'xmax': 509, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 348, 'ymin': 83, 'xmax': 512, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 347, 'ymin': 81, 'xmax': 513, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 348, 'ymin': 81, 'xmax': 512, 'ymax': 174}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 9, 'ymin': 3, 'xmax': 854, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.5, 'box': {'xmin': 15, 'ymin': 3, 'xmax': 850, 'ymax': 477}}
# {'class': 'AngelaMerkel', 'confidence': 0.55859375, 'box': {'xmin': 15, 'ymin': 3, 'xmax': 850, 'ymax': 477}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 348, 'ymin': 80, 'xmax': 512, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 346, 'ymin': 77, 'xmax': 514, 'ymax': 171}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 351, 'ymin': 80, 'xmax': 517, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 349, 'ymin': 78, 'xmax': 515, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 355, 'ymin': 83, 'xmax': 517, 'ymax': 174}}
# {'class': 'MichaelJackson', 'confidence': 0.4140625, 'box': {'xmin': 351, 'ymin': 86, 'xmax': 521, 'ymax': 183}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 361, 'ymin': 82, 'xmax': 533, 'ymax': 182}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 355, 'ymin': 80, 'xmax': 534, 'ymax': 184}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 360, 'ymin': 79, 'xmax': 530, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 354, 'ymin': 79, 'xmax': 530, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 355, 'ymin': 79, 'xmax': 529, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 354, 'ymin': 79, 'xmax': 526, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 356, 'ymin': 79, 'xmax': 528, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 356, 'ymin': 80, 'xmax': 528, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 355, 'ymin': 80, 'xmax': 529, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 362, 'ymin': 79, 'xmax': 532, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 357, 'ymin': 81, 'xmax': 538, 'ymax': 186}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 356, 'ymin': 85, 'xmax': 532, 'ymax': 186}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 359, 'ymin': 89, 'xmax': 533, 'ymax': 189}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 360, 'ymin': 92, 'xmax': 528, 'ymax': 188}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 361, 'ymin': 93, 'xmax': 527, 'ymax': 187}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 358, 'ymin': 91, 'xmax': 530, 'ymax': 189}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 357, 'ymin': 88, 'xmax': 536, 'ymax': 188}}
# {'class': 'MichaelJackson', 'confidence': 0.5, 'box': {'xmin': 356, 'ymin': 86, 'xmax': 532, 'ymax': 187}}
# {'class': 'MichaelJackson', 'confidence': 0.47265625, 'box': {'xmin': 356, 'ymin': 85, 'xmax': 532, 'ymax': 186}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 355, 'ymin': 84, 'xmax': 538, 'ymax': 187}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 358, 'ymin': 81, 'xmax': 542, 'ymax': 186}}
# {'class': 'AngelaMerkel', 'confidence': 0.734375, 'box': {'xmin': 356, 'ymin': 83, 'xmax': 537, 'ymax': 186}}
# {'class': 'AngelaMerkel', 'confidence': 0.734375, 'box': {'xmin': 359, 'ymin': 82, 'xmax': 538, 'ymax': 184}}
# {'class': 'AngelaMerkel', 'confidence': 0.6640625, 'box': {'xmin': 358, 'ymin': 79, 'xmax': 539, 'ymax': 182}}
# {'class': 'AngelaMerkel', 'confidence': 0.640625, 'box': {'xmin': 360, 'ymin': 79, 'xmax': 541, 'ymax': 182}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 360, 'ymin': 80, 'xmax': 541, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 361, 'ymin': 78, 'xmax': 540, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 366, 'ymin': 75, 'xmax': 548, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 365, 'ymin': 73, 'xmax': 548, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 366, 'ymin': 73, 'xmax': 552, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 366, 'ymin': 72, 'xmax': 552, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 368, 'ymin': 74, 'xmax': 549, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 367, 'ymin': 73, 'xmax': 551, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 371, 'ymin': 74, 'xmax': 550, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 368, 'ymin': 75, 'xmax': 554, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 373, 'ymin': 77, 'xmax': 555, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 373, 'ymin': 77, 'xmax': 555, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 372, 'ymin': 76, 'xmax': 561, 'ymax': 182}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 373, 'ymin': 78, 'xmax': 562, 'ymax': 183}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 380, 'ymin': 79, 'xmax': 566, 'ymax': 185}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 380, 'ymin': 79, 'xmax': 569, 'ymax': 185}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 383, 'ymin': 80, 'xmax': 571, 'ymax': 187}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 383, 'ymin': 80, 'xmax': 571, 'ymax': 187}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 384, 'ymin': 80, 'xmax': 570, 'ymax': 184}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 386, 'ymin': 82, 'xmax': 568, 'ymax': 185}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 5, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 387, 'ymin': 81, 'xmax': 566, 'ymax': 186}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 390, 'ymin': 81, 'xmax': 571, 'ymax': 183}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 389, 'ymin': 81, 'xmax': 575, 'ymax': 186}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 10, 'ymin': 0, 'xmax': 844, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 389, 'ymin': 80, 'xmax': 572, 'ymax': 184}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 10, 'ymin': 0, 'xmax': 844, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 10, 'ymin': 0, 'xmax': 844, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'MacKenzieScott', 'confidence': 0.44140625, 'box': {'xmin': 5, 'ymin': 3, 'xmax': 849, 'ymax': 477}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'MacKenzieScott', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 381, 'ymin': 83, 'xmax': 560, 'ymax': 183}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 383, 'ymin': 81, 'xmax': 560, 'ymax': 183}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 383, 'ymin': 82, 'xmax': 557, 'ymax': 182}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 382, 'ymin': 83, 'xmax': 561, 'ymax': 184}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 380, 'ymin': 83, 'xmax': 558, 'ymax': 185}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 380, 'ymin': 83, 'xmax': 558, 'ymax': 185}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 380, 'ymin': 81, 'xmax': 559, 'ymax': 183}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 379, 'ymin': 83, 'xmax': 556, 'ymax': 184}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 381, 'ymin': 82, 'xmax': 557, 'ymax': 182}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 378, 'ymin': 82, 'xmax': 557, 'ymax': 182}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 381, 'ymin': 81, 'xmax': 557, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 382, 'ymin': 79, 'xmax': 556, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 381, 'ymin': 79, 'xmax': 557, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 472}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 381, 'ymin': 79, 'xmax': 557, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 10, 'ymin': 0, 'xmax': 844, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 380, 'ymin': 79, 'xmax': 558, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 5, 'ymin': 0, 'xmax': 849, 'ymax': 471}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 381, 'ymin': 81, 'xmax': 557, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 380, 'ymin': 78, 'xmax': 557, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 380, 'ymin': 78, 'xmax': 558, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 0, 'ymin': 2, 'xmax': 845, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 376, 'ymin': 78, 'xmax': 557, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 376, 'ymin': 78, 'xmax': 557, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 373, 'ymin': 77, 'xmax': 555, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 372, 'ymin': 78, 'xmax': 549, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 370, 'ymin': 77, 'xmax': 547, 'ymax': 178}}
# {'class': 'MichaelJackson', 'confidence': 0.5, 'box': {'xmin': 369, 'ymin': 78, 'xmax': 548, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 372, 'ymin': 79, 'xmax': 549, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 369, 'ymin': 78, 'xmax': 544, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 367, 'ymin': 78, 'xmax': 542, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 364, 'ymin': 79, 'xmax': 536, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 365, 'ymin': 78, 'xmax': 542, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 361, 'ymin': 81, 'xmax': 531, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 363, 'ymin': 77, 'xmax': 537, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.640625, 'box': {'xmin': 363, 'ymin': 77, 'xmax': 537, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 362, 'ymin': 79, 'xmax': 532, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 361, 'ymin': 77, 'xmax': 533, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.640625, 'box': {'xmin': 355, 'ymin': 79, 'xmax': 529, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 355, 'ymin': 81, 'xmax': 525, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 359, 'ymin': 81, 'xmax': 536, 'ymax': 183}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 357, 'ymin': 80, 'xmax': 532, 'ymax': 181}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 356, 'ymin': 81, 'xmax': 533, 'ymax': 183}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 351, 'ymin': 86, 'xmax': 529, 'ymax': 189}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 352, 'ymin': 90, 'xmax': 533, 'ymax': 192}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 480}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 9, 'ymin': 0, 'xmax': 854, 'ymax': 480}}
# {'class': 'MacKenzieScott', 'confidence': 0.4140625, 'box': {'xmin': 5, 'ymin': 3, 'xmax': 849, 'ymax': 477}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 354, 'ymin': 79, 'xmax': 530, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 357, 'ymin': 81, 'xmax': 527, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 358, 'ymin': 80, 'xmax': 526, 'ymax': 175}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 355, 'ymin': 78, 'xmax': 525, 'ymax': 175}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 357, 'ymin': 77, 'xmax': 523, 'ymax': 171}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 356, 'ymin': 77, 'xmax': 524, 'ymax': 171}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 353, 'ymin': 75, 'xmax': 523, 'ymax': 170}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 353, 'ymin': 75, 'xmax': 523, 'ymax': 170}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 352, 'ymin': 73, 'xmax': 524, 'ymax': 171}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 353, 'ymin': 73, 'xmax': 523, 'ymax': 168}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 352, 'ymin': 70, 'xmax': 524, 'ymax': 168}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 350, 'ymin': 71, 'xmax': 522, 'ymax': 169}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 354, 'ymin': 73, 'xmax': 522, 'ymax': 168}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 350, 'ymin': 71, 'xmax': 526, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 352, 'ymin': 74, 'xmax': 524, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.6640625, 'box': {'xmin': 352, 'ymin': 75, 'xmax': 524, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.69140625, 'box': {'xmin': 350, 'ymin': 77, 'xmax': 522, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.69140625, 'box': {'xmin': 351, 'ymin': 77, 'xmax': 521, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 354, 'ymin': 81, 'xmax': 524, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 356, 'ymin': 79, 'xmax': 526, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 356, 'ymin': 77, 'xmax': 526, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 353, 'ymin': 76, 'xmax': 523, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 355, 'ymin': 74, 'xmax': 529, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 352, 'ymin': 73, 'xmax': 528, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 355, 'ymin': 74, 'xmax': 529, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 356, 'ymin': 75, 'xmax': 528, 'ymax': 171}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 356, 'ymin': 74, 'xmax': 532, 'ymax': 174}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 357, 'ymin': 74, 'xmax': 536, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 359, 'ymin': 75, 'xmax': 538, 'ymax': 175}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 361, 'ymin': 72, 'xmax': 538, 'ymax': 174}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 360, 'ymin': 75, 'xmax': 537, 'ymax': 175}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 363, 'ymin': 76, 'xmax': 538, 'ymax': 174}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 365, 'ymin': 77, 'xmax': 542, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 365, 'ymin': 77, 'xmax': 535, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 363, 'ymin': 76, 'xmax': 538, 'ymax': 175}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 365, 'ymin': 76, 'xmax': 540, 'ymax': 174}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 364, 'ymin': 75, 'xmax': 540, 'ymax': 174}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 370, 'ymin': 74, 'xmax': 547, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 375, 'ymin': 74, 'xmax': 551, 'ymax': 174}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 472}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 381, 'ymin': 71, 'xmax': 555, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 374, 'ymin': 89, 'xmax': 565, 'ymax': 196}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 373, 'ymin': 94, 'xmax': 557, 'ymax': 197}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 373, 'ymin': 96, 'xmax': 552, 'ymax': 198}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 367, 'ymin': 93, 'xmax': 550, 'ymax': 196}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 365, 'ymin': 90, 'xmax': 548, 'ymax': 195}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 365, 'ymin': 91, 'xmax': 548, 'ymax': 194}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 363, 'ymin': 89, 'xmax': 542, 'ymax': 191}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 358, 'ymin': 84, 'xmax': 539, 'ymax': 187}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 357, 'ymin': 84, 'xmax': 540, 'ymax': 187}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 359, 'ymin': 80, 'xmax': 540, 'ymax': 184}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 360, 'ymin': 80, 'xmax': 539, 'ymax': 184}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 357, 'ymin': 76, 'xmax': 538, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 355, 'ymin': 75, 'xmax': 534, 'ymax': 177}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 353, 'ymin': 74, 'xmax': 532, 'ymax': 175}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 354, 'ymin': 73, 'xmax': 530, 'ymax': 174}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 349, 'ymin': 71, 'xmax': 530, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 344, 'ymin': 71, 'xmax': 525, 'ymax': 174}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 348, 'ymin': 72, 'xmax': 524, 'ymax': 172}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 345, 'ymin': 72, 'xmax': 523, 'ymax': 173}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 345, 'ymin': 75, 'xmax': 524, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 347, 'ymin': 81, 'xmax': 514, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 342, 'ymin': 82, 'xmax': 514, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 342, 'ymin': 84, 'xmax': 518, 'ymax': 185}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 344, 'ymin': 89, 'xmax': 516, 'ymax': 187}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 475}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 347, 'ymin': 93, 'xmax': 517, 'ymax': 190}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 346, 'ymin': 92, 'xmax': 518, 'ymax': 190}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 4, 'ymin': 0, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 349, 'ymin': 98, 'xmax': 519, 'ymax': 194}}
# {'class': 'HeleneFischer', 'confidence': 0.5, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 350, 'ymin': 96, 'xmax': 522, 'ymax': 193}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'HeleneFischer', 'confidence': 0.47265625, 'box': {'xmin': 352, 'ymin': 92, 'xmax': 528, 'ymax': 191}}
# {'class': 'HeleneFischer', 'confidence': 0.4140625, 'box': {'xmin': 349, 'ymin': 90, 'xmax': 527, 'ymax': 190}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 351, 'ymin': 91, 'xmax': 525, 'ymax': 190}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 348, 'ymin': 87, 'xmax': 527, 'ymax': 189}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 350, 'ymin': 83, 'xmax': 531, 'ymax': 187}}
# {'class': 'HeleneFischer', 'confidence': 0.640625, 'box': {'xmin': 350, 'ymin': 78, 'xmax': 536, 'ymax': 186}}
# {'class': 'HeleneFischer', 'confidence': 0.640625, 'box': {'xmin': 356, 'ymin': 78, 'xmax': 533, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 355, 'ymin': 78, 'xmax': 534, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 355, 'ymin': 78, 'xmax': 534, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 355, 'ymin': 78, 'xmax': 534, 'ymax': 180}}
# {'class': 'HeleneFischer', 'confidence': 0.640625, 'box': {'xmin': 356, 'ymin': 76, 'xmax': 533, 'ymax': 176}}
# {'class': 'HeleneFischer', 'confidence': 0.52734375, 'box': {'xmin': 353, 'ymin': 76, 'xmax': 532, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.44140625, 'box': {'xmin': 353, 'ymin': 78, 'xmax': 532, 'ymax': 178}}
# {'class': 'HeleneFischer', 'confidence': 0.55859375, 'box': {'xmin': 354, 'ymin': 78, 'xmax': 530, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.5859375, 'box': {'xmin': 353, 'ymin': 78, 'xmax': 532, 'ymax': 179}}
# {'class': 'HeleneFischer', 'confidence': 0.61328125, 'box': {'xmin': 353, 'ymin': 82, 'xmax': 532, 'ymax': 182}}
# {'class': 'AngelaMerkel', 'confidence': 0.52734375, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
# {'class': 'AngelaMerkel', 'confidence': 0.4140625, 'box': {'xmin': 4, 'ymin': 2, 'xmax': 850, 'ymax': 478}}
